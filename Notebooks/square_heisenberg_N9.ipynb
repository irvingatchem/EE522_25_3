# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
import qiskit_aer
import numpy as np

backend = qiskit_aer.AerSimulator()

shots = 1024

qc = QuantumCircuit()

q = QuantumRegister(9, 'q')

qc.add_register(q)

qc.cx(q[0], q[3])
qc.rz(1, q[3])
qc.cx(q[0], q[3])
qc.rx(np.pi / 2, q[0])
qc.rx(np.pi / 2, q[3])
qc.cx(q[0], q[3])
qc.rz(1, q[3])
qc.cx(q[0], q[3])
qc.rx(-np.pi / 2, q[0])
qc.rx(-np.pi / 2, q[3])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[3])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[3])
qc.cx(q[0], q[3])
qc.rz(1, q[3])
qc.cx(q[0], q[3])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[3])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[3])
qc.cx(q[0], q[3])
qc.rz(1, q[3])
qc.cx(q[0], q[3])
qc.rx(np.pi / 2, q[0])
qc.rx(np.pi / 2, q[3])
qc.cx(q[0], q[3])
qc.rz(1, q[3])
qc.cx(q[0], q[3])
qc.rx(-np.pi / 2, q[0])
qc.rx(-np.pi / 2, q[3])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[3])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[3])
qc.cx(q[0], q[3])
qc.rz(1, q[3])
qc.cx(q[0], q[3])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[3])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[3])
qc.cx(q[0], q[1])
qc.rz(1, q[1])
qc.cx(q[0], q[1])
qc.rx(np.pi / 2, q[0])
qc.rx(np.pi / 2, q[1])
qc.cx(q[0], q[1])
qc.rz(1, q[1])
qc.cx(q[0], q[1])
qc.rx(-np.pi / 2, q[0])
qc.rx(-np.pi / 2, q[1])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[1])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[1])
qc.cx(q[0], q[1])
qc.rz(1, q[1])
qc.cx(q[0], q[1])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[1])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[1])
qc.cx(q[0], q[1])
qc.rz(1, q[1])
qc.cx(q[0], q[1])
qc.rx(np.pi / 2, q[0])
qc.rx(np.pi / 2, q[1])
qc.cx(q[0], q[1])
qc.rz(1, q[1])
qc.cx(q[0], q[1])
qc.rx(-np.pi / 2, q[0])
qc.rx(-np.pi / 2, q[1])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[1])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[1])
qc.cx(q[0], q[1])
qc.rz(1, q[1])
qc.cx(q[0], q[1])
qc.ry(np.pi / 2, q[0])
qc.ry(np.pi / 2, q[1])
qc.rx(np.pi, q[0])
qc.rx(np.pi, q[1])
qc.rz(-0.4833583353015487, q[0])
qc.cx(q[1], q[4])
qc.rz(1, q[4])
qc.cx(q[1], q[4])
qc.rx(np.pi / 2, q[1])
qc.rx(np.pi / 2, q[4])
qc.cx(q[1], q[4])
qc.rz(1, q[4])
qc.cx(q[1], q[4])
qc.rx(-np.pi / 2, q[1])
qc.rx(-np.pi / 2, q[4])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[4])
qc.cx(q[1], q[4])
qc.rz(1, q[4])
qc.cx(q[1], q[4])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[4])
qc.cx(q[1], q[4])
qc.rz(1, q[4])
qc.cx(q[1], q[4])
qc.rx(np.pi / 2, q[1])
qc.rx(np.pi / 2, q[4])
qc.cx(q[1], q[4])
qc.rz(1, q[4])
qc.cx(q[1], q[4])
qc.rx(-np.pi / 2, q[1])
qc.rx(-np.pi / 2, q[4])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[4])
qc.cx(q[1], q[4])
qc.rz(1, q[4])
qc.cx(q[1], q[4])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[4])
qc.cx(q[1], q[2])
qc.rz(1, q[2])
qc.cx(q[1], q[2])
qc.rx(np.pi / 2, q[1])
qc.rx(np.pi / 2, q[2])
qc.cx(q[1], q[2])
qc.rz(1, q[2])
qc.cx(q[1], q[2])
qc.rx(-np.pi / 2, q[1])
qc.rx(-np.pi / 2, q[2])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[2])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[2])
qc.cx(q[1], q[2])
qc.rz(1, q[2])
qc.cx(q[1], q[2])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[2])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[2])
qc.cx(q[1], q[2])
qc.rz(1, q[2])
qc.cx(q[1], q[2])
qc.rx(np.pi / 2, q[1])
qc.rx(np.pi / 2, q[2])
qc.cx(q[1], q[2])
qc.rz(1, q[2])
qc.cx(q[1], q[2])
qc.rx(-np.pi / 2, q[1])
qc.rx(-np.pi / 2, q[2])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[2])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[2])
qc.cx(q[1], q[2])
qc.rz(1, q[2])
qc.cx(q[1], q[2])
qc.ry(np.pi / 2, q[1])
qc.ry(np.pi / 2, q[2])
qc.rx(np.pi, q[1])
qc.rx(np.pi, q[2])
qc.rz(-1.311081899823388, q[1])
qc.cx(q[2], q[5])
qc.rz(1, q[5])
qc.cx(q[2], q[5])
qc.rx(np.pi / 2, q[2])
qc.rx(np.pi / 2, q[5])
qc.cx(q[2], q[5])
qc.rz(1, q[5])
qc.cx(q[2], q[5])
qc.rx(-np.pi / 2, q[2])
qc.rx(-np.pi / 2, q[5])
qc.ry(np.pi / 2, q[2])
qc.ry(np.pi / 2, q[5])
qc.rx(np.pi, q[2])
qc.rx(np.pi, q[5])
qc.cx(q[2], q[5])
qc.rz(1, q[5])
qc.cx(q[2], q[5])
qc.ry(np.pi / 2, q[2])
qc.ry(np.pi / 2, q[5])
qc.rx(np.pi, q[2])
qc.rx(np.pi, q[5])
qc.cx(q[2], q[5])
qc.rz(1, q[5])
qc.cx(q[2], q[5])
qc.rx(np.pi / 2, q[2])
qc.rx(np.pi / 2, q[5])
qc.cx(q[2], q[5])
qc.rz(1, q[5])
qc.cx(q[2], q[5])
qc.rx(-np.pi / 2, q[2])
qc.rx(-np.pi / 2, q[5])
qc.ry(np.pi / 2, q[2])
qc.ry(np.pi / 2, q[5])
qc.rx(np.pi, q[2])
qc.rx(np.pi, q[5])
qc.cx(q[2], q[5])
qc.rz(1, q[5])
qc.cx(q[2], q[5])
qc.ry(np.pi / 2, q[2])
qc.ry(np.pi / 2, q[5])
qc.rx(np.pi, q[2])
qc.rx(np.pi, q[5])
qc.rz(-1.4170141939906804, q[2])
qc.cx(q[3], q[6])
qc.rz(1, q[6])
qc.cx(q[3], q[6])
qc.rx(np.pi / 2, q[3])
qc.rx(np.pi / 2, q[6])
qc.cx(q[3], q[6])
qc.rz(1, q[6])
qc.cx(q[3], q[6])
qc.rx(-np.pi / 2, q[3])
qc.rx(-np.pi / 2, q[6])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[6])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[6])
qc.cx(q[3], q[6])
qc.rz(1, q[6])
qc.cx(q[3], q[6])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[6])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[6])
qc.cx(q[3], q[6])
qc.rz(1, q[6])
qc.cx(q[3], q[6])
qc.rx(np.pi / 2, q[3])
qc.rx(np.pi / 2, q[6])
qc.cx(q[3], q[6])
qc.rz(1, q[6])
qc.cx(q[3], q[6])
qc.rx(-np.pi / 2, q[3])
qc.rx(-np.pi / 2, q[6])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[6])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[6])
qc.cx(q[3], q[6])
qc.rz(1, q[6])
qc.cx(q[3], q[6])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[6])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[6])
qc.cx(q[3], q[4])
qc.rz(1, q[4])
qc.cx(q[3], q[4])
qc.rx(np.pi / 2, q[3])
qc.rx(np.pi / 2, q[4])
qc.cx(q[3], q[4])
qc.rz(1, q[4])
qc.cx(q[3], q[4])
qc.rx(-np.pi / 2, q[3])
qc.rx(-np.pi / 2, q[4])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[4])
qc.cx(q[3], q[4])
qc.rz(1, q[4])
qc.cx(q[3], q[4])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[4])
qc.cx(q[3], q[4])
qc.rz(1, q[4])
qc.cx(q[3], q[4])
qc.rx(np.pi / 2, q[3])
qc.rx(np.pi / 2, q[4])
qc.cx(q[3], q[4])
qc.rz(1, q[4])
qc.cx(q[3], q[4])
qc.rx(-np.pi / 2, q[3])
qc.rx(-np.pi / 2, q[4])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[4])
qc.cx(q[3], q[4])
qc.rz(1, q[4])
qc.cx(q[3], q[4])
qc.ry(np.pi / 2, q[3])
qc.ry(np.pi / 2, q[4])
qc.rx(np.pi, q[3])
qc.rx(np.pi, q[4])
qc.rz(-1.7697309322476698, q[3])
qc.cx(q[4], q[7])
qc.rz(1, q[7])
qc.cx(q[4], q[7])
qc.rx(np.pi / 2, q[4])
qc.rx(np.pi / 2, q[7])
qc.cx(q[4], q[7])
qc.rz(1, q[7])
qc.cx(q[4], q[7])
qc.rx(-np.pi / 2, q[4])
qc.rx(-np.pi / 2, q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[7])
qc.rz(1, q[7])
qc.cx(q[4], q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[7])
qc.rz(1, q[7])
qc.cx(q[4], q[7])
qc.rx(np.pi / 2, q[4])
qc.rx(np.pi / 2, q[7])
qc.cx(q[4], q[7])
qc.rz(1, q[7])
qc.cx(q[4], q[7])
qc.rx(-np.pi / 2, q[4])
qc.rx(-np.pi / 2, q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[7])
qc.rz(1, q[7])
qc.cx(q[4], q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rz(1, q[5])
qc.rz(1, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rx(np.pi / 2, q[4])
qc.rx(np.pi / 2, q[5])
qc.rx(np.pi / 2, q[6])
qc.rx(np.pi / 2, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rz(1, q[5])
qc.rz(1, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rx(-np.pi / 2, q[4])
qc.rx(-np.pi / 2, q[5])
qc.rx(-np.pi / 2, q[6])
qc.rx(-np.pi / 2, q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[6])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[6])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rz(1, q[5])
qc.rz(1, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[6])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[6])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rz(1, q[5])
qc.rz(1, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rx(np.pi / 2, q[4])
qc.rx(np.pi / 2, q[5])
qc.rx(np.pi / 2, q[6])
qc.rx(np.pi / 2, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rz(1, q[5])
qc.rz(1, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rx(-np.pi / 2, q[4])
qc.rx(-np.pi / 2, q[5])
qc.rx(-np.pi / 2, q[6])
qc.rx(-np.pi / 2, q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[6])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[6])
qc.rx(np.pi, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.rz(1, q[5])
qc.rz(1, q[7])
qc.cx(q[4], q[5])
qc.cx(q[6], q[7])
qc.ry(np.pi / 2, q[4])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[6])
qc.ry(np.pi / 2, q[7])
qc.rx(np.pi, q[4])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[6])
qc.rx(np.pi, q[7])
qc.rz(-1.560914598304639, q[4])
qc.rz(-0.36313694747249103, q[6])
qc.cx(q[5], q[8])
qc.rz(1, q[8])
qc.cx(q[5], q[8])
qc.rx(np.pi / 2, q[5])
qc.rx(np.pi / 2, q[8])
qc.cx(q[5], q[8])
qc.rz(1, q[8])
qc.cx(q[5], q[8])
qc.rx(-np.pi / 2, q[5])
qc.rx(-np.pi / 2, q[8])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[8])
qc.cx(q[5], q[8])
qc.rz(1, q[8])
qc.cx(q[5], q[8])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[8])
qc.cx(q[5], q[8])
qc.rz(1, q[8])
qc.cx(q[5], q[8])
qc.rx(np.pi / 2, q[5])
qc.rx(np.pi / 2, q[8])
qc.cx(q[5], q[8])
qc.rz(1, q[8])
qc.cx(q[5], q[8])
qc.rx(-np.pi / 2, q[5])
qc.rx(-np.pi / 2, q[8])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[8])
qc.cx(q[5], q[8])
qc.rz(1, q[8])
qc.cx(q[5], q[8])
qc.ry(np.pi / 2, q[5])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[5])
qc.rx(np.pi, q[8])
qc.rz(-0.21235126602212873, q[5])
qc.cx(q[7], q[8])
qc.rz(1, q[8])
qc.cx(q[7], q[8])
qc.rx(np.pi / 2, q[7])
qc.rx(np.pi / 2, q[8])
qc.cx(q[7], q[8])
qc.rz(1, q[8])
qc.cx(q[7], q[8])
qc.rx(-np.pi / 2, q[7])
qc.rx(-np.pi / 2, q[8])
qc.ry(np.pi / 2, q[7])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[7])
qc.rx(np.pi, q[8])
qc.cx(q[7], q[8])
qc.rz(1, q[8])
qc.cx(q[7], q[8])
qc.ry(np.pi / 2, q[7])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[7])
qc.rx(np.pi, q[8])
qc.cx(q[7], q[8])
qc.rz(1, q[8])
qc.cx(q[7], q[8])
qc.rx(np.pi / 2, q[7])
qc.rx(np.pi / 2, q[8])
qc.cx(q[7], q[8])
qc.rz(1, q[8])
qc.cx(q[7], q[8])
qc.rx(-np.pi / 2, q[7])
qc.rx(-np.pi / 2, q[8])
qc.ry(np.pi / 2, q[7])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[7])
qc.rx(np.pi, q[8])
qc.cx(q[7], q[8])
qc.rz(1, q[8])
qc.cx(q[7], q[8])
qc.ry(np.pi / 2, q[7])
qc.ry(np.pi / 2, q[8])
qc.rx(np.pi, q[7])
qc.rx(np.pi, q[8])
qc.rz(0.8354896414891244, q[7])
qc.rz(0.3311538078660634, q[8])

# job = execute(qc, backend=backend, shots=shots)
# job_result = job.result()
# print(job_result.get_counts(qc))

qc.draw("mpl")
